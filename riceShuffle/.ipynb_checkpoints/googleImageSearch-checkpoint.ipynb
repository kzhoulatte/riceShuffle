# %% [markdown]
# ## Google image search API

# %%
from googleapiclient.discovery import build
import pprint

my_api_key = "AIzaSyAteS9DtwkhCxaJLfnp9aP9iiY3I895FfM"
my_cse_id = "006080186136996849614:rckq-s9yqak"

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search(
    'rice', my_api_key, my_cse_id, num=10)
for result in results:
    pprint.pprint(result)
# Out:
# {'cacheId': '_RQVSE7B_BwJ',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/embed/.../tumblelog?...rice...rice...',
#  'htmlFormattedUrl': 'https://www.tumblr.com/embed/.../tumblelog?...<b>rice</b>...<b>rice</b>...',
#  'htmlSnippet': 'Sep 10, 2013 <b>...</b> Open for lunch, dinner, and latenight '
#                 'in the RMC basement since 1975, Willy&#39;s <br>\n'
#                 'Pub is <b>Rice</b> University&#39;s oldest and least family '
#                 'friendly&nbsp;...',
#  'htmlTitle': 'Willy&#39;s Pub',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/embed/clickthrough/9b2ceGhSz9tP3GGus1hjyw/60849951298/tumblelog?url=http%3A%2F%2Fwillyspub.rice.edu%2F&refUrl=http%3A%2F%2Fwillyspub.rice.edu%2Fpost%2F60849951298%2Fim-trying-to-pay-pub-for-an-events%2Fembed&isAMP=false',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/50e1a430ae8cef9c6b4f84564b8af527/tumblr_mfpjuwOZx41s0b7u5o1_1280.jpg'}],
#              'cse_thumbnail': [{'height': '190',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcR0lm4oYmFQZsMitS9PeFSkdjBUoe-LGigTJSBShb29BQQl2Txcod_Sl9m2',
#                                 'width': '266'}],
#              'metatags': [{'al:android:app_name': 'Tumblr',
#                            'al:android:package': 'com.tumblr',
#                            'al:android:url': 'tumblr://x-callback-url/blog?blogName=willyspub',
#                            'al:ios:app_name': 'Tumblr',
#                            'al:ios:app_store_id': '305343404',
#                            'al:ios:url': 'tumblr://x-callback-url/blog?blogName=willyspub',
#                            'fb:app_id': '48119224995',
#                            'og:image': 'https://66.media.tumblr.com/avatar_d1cb81e4dc58_128.pnj',
#                            'og:type': 'tumblr-feed:tumblelog',
#                            'og:url': 'http://willyspub.rice.edu/?og=1',
#                            'theme-color': '#35465D',
#                            'twitter:app:id:googleplay': 'com.tumblr',
#                            'twitter:app:id:ipad': '305343404',
#                            'twitter:app:id:iphone': '305343404',
#                            'twitter:app:name:googleplay': 'Tumblr',
#                            'twitter:app:name:ipad': 'Tumblr',
#                            'twitter:app:name:iphone': 'Tumblr',
#                            'twitter:app:url:googleplay': 'tumblr://x-callback-url/blog?blogName=willyspub&referrer=twitter-cards',
#                            'twitter:app:url:ipad': 'tumblr://x-callback-url/blog?blogName=willyspub&referrer=twitter-cards',
#                            'twitter:app:url:iphone': 'tumblr://x-callback-url/blog?blogName=willyspub&referrer=twitter-cards',
#                            'twitter:card': 'app',
#                            'twitter:description': 'willyspub',
#                            'twitter:site': 'tumblr',
#                            'twitter:title': 'willyspub',
#                            'viewport': 'width=device-width, initial-scale=1.0, '
#                                        'maximum-scale=1.0, user-scalable=no'}]},
#  'snippet': 'Sep 10, 2013 ... Open for lunch, dinner, and latenight in the RMC '
#             "basement since 1975, Willy's \n"
#             "Pub is Rice University's oldest and least family friendly\xa0...",
#  'title': "Willy's Pub"}
# {'cacheId': '5iiQmgwBRioJ',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/tagged/damien+rice+lyrics',
#  'htmlFormattedUrl': 'https://www.tumblr.com/tagged/damien+<b>rice</b>+lyrics',
#  'htmlSnippet': 'this quote is from a song called “9 crimes” by damien '
#                 '<b>rice</b>. the piano is so simple, <br>\n'
#                 'yet so beautiful. the same lovely melody persists throughout '
#                 'the whole song.',
#  'htmlTitle': 'damien <b>rice</b> lyrics | Tumblr',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/tagged/damien+rice+lyrics',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/329cf09189b3a11c59fdd7c64535b042/tumblr_no3y8lFOTx1uv9pwvo1_400.jpg'}],
#              'cse_thumbnail': [{'height': '183',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTsxuoIJqLKNAGh_dV6y451GwfXmYw9nzWAcEel2O72QTA4st7bPKpwWq0-',
#                                 'width': '275'}],
#              'metatags': [{'application-name': 'Tumblr',
#                            'msapplication-tilecolor': '#3645d',
#                            'msapplication-tileimage': 'https://assets.tumblr.com/images/msfavicon.png?_v=245323c5cb69e705ea213d9ed60e543a',
#                            'p:domain_verify': 'd06c4fa470a9a6935c9a7b43d57eb7d2',
#                            'theme-color': '#35465D',
#                            'tumblr-form-key': '!1231553863334|wqgeCuwYufrNh8KhOBDbO5Pilw',
#                            'tumblr-gpop': 'Tumblr',
#                            'viewport': 'initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no'}]},
#  'snippet': 'this quote is from a song called “9 crimes” by damien rice. the '
#             'piano is so simple, \n'
#             'yet so beautiful. the same lovely melody persists throughout the '
#             'whole song.',
#  'title': 'damien rice lyrics | Tumblr'}
# {'cacheId': 'LCgBZIucdJUJ',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/embed/.../notes?...rice...rice...',
#  'htmlFormattedUrl': 'https://www.tumblr.com/embed/.../notes?...<b>rice</b>...<b>rice</b>...',
#  'htmlSnippet': 'I am in love with this recipe. I have been craving Chinese '
#                 'food a lot lately. <br>\n'
#                 'Whenever we order in I usually end up eating too much fried '
#                 '<b>rice</b>. Then the next <br>\n'
#                 'day I&nbsp;...',
#  'htmlTitle': 'a Love a fare — Light Cauliflower Fried <b>Rice</b> (can I call '
#               'this...',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/embed/clickthrough/hwy9uVPwT-ksRq9cEbtMIA/62410826939/notes?url=http%3A%2F%2Faloveafare.com%2Fpost%2F62410826939%2Flight-cauliflower-fried-rice-can-i-call-this%23notes&refUrl=http%3A%2F%2Faloveafare.com%2Fpost%2F62410826939%2Flight-cauliflower-fried-rice-can-i-call-this%2Fembed&isAMP=false',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/90675490e8b2ccd781cf02708f24b254/tumblr_inline_mtlv1wbf7H1r4bmc5.jpg'}],
#              'cse_thumbnail': [{'height': '275',
#                                 'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQSxT19EGQmFMncDJw4zse1CQTezH1HEM_NUpOMlbVFcdNjkGSDaDKO-YQ',
#                                 'width': '183'}],
#              'metatags': [{'apple-mobile-web-app-capable': 'yes',
#                            'og:description': 'Light Cauliflower Fried Rice '
#                                              '(can I call this...',
#                            'og:site_name': 'a Love a fare',
#                            'og:title': 'a Love a fare — Light Cauliflower '
#                                        'Fried Rice (can I call this...',
#                            'og:type': 'article',
#                            'og:url': 'http://aloveafare.com/post/62410826939/light-cauliflower-fried-rice-can-i-call-this',
#                            'viewport': 'width=device-width, initial-scale=1.0, '
#                                        'maximum-scale=1.0, user-scalable=0',
#                            '”keywords”': '”,healthy'}]},
#  'snippet': 'I am in love with this recipe. I have been craving Chinese food a '
#             'lot lately. \n'
#             'Whenever we order in I usually end up eating too much fried rice. '
#             'Then the next \n'
#             'day I\xa0...',
#  'title': 'a Love a fare — Light Cauliflower Fried Rice (can I call this...'}
# {'cacheId': 'niNSBVZQFbEJ',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/tagged/anne-rice',
#  'htmlFormattedUrl': 'https://www.tumblr.com/tagged/anne-<b>rice</b>',
#  'htmlSnippet': 'Anne <b>Rice</b> went Christian and didn&#39;t want her books '
#                 'to be SUPER FUCKING <br>\n'
#                 'QUEER anymore. Creators&#39; views on what they&#39;ve made '
#                 'can change over the&nbsp;...',
#  'htmlTitle': 'anne <b>rice</b> | Tumblr',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/tagged/anne-rice',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/7e76a24f7f4b4a3611b57645b62c203f/tumblr_om4t3oJtwu1qiv7jbo1_500.png'}],
#              'cse_thumbnail': [{'height': '191',
#                                 'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSLnlYqb44cF1Qq29QY6qzD0AQo4swwPTq4x7V5ACr5W9kG8LVEfQs-ExGd',
#                                 'width': '264'}],
#              'metatags': [{'application-name': 'Tumblr',
#                            'msapplication-tilecolor': '#3645d',
#                            'msapplication-tileimage': 'https://assets.tumblr.com/images/msfavicon.png?_v=245323c5cb69e705ea213d9ed60e543a',
#                            'p:domain_verify': 'd06c4fa470a9a6935c9a7b43d57eb7d2',
#                            'theme-color': '#35465D',
#                            'tumblr-form-key': '!1231553887288|fuFoAs8NOTs2RxXfkGbQBrWKvE',
#                            'tumblr-gpop': 'Tumblr',
#                            'viewport': 'initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no'}]},
#  'snippet': "Anne Rice went Christian and didn't want her books to be SUPER "
#             'FUCKING \n'
#             "QUEER anymore. Creators' views on what they've made can change "
#             'over the\xa0...',
#  'title': 'anne rice | Tumblr'}
# {'cacheId': 'Y1gsSwTw4R4J',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/.../notes?...rice%23notes...rice%2Fembed...',
#  'htmlFormattedUrl': 'https://www.tumblr.com/.../notes?...<b>rice</b>%23notes...<b>rice</b>%2Fembed...',
#  'htmlSnippet': 'Mar 27, 2015 <b>...</b> Matta <b>rice</b> is an ancient '
#                 '<b>rice</b> variety hailing from Kerala, South India. Its '
#                 'plump <br>\n'
#                 'little grains have a softy rosy color – it is also known as '
#                 'rosematta&nbsp;...',
#  'htmlTitle': '— Can we be honest with you? We&#39;re probably a bit...',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/embed/clickthrough/q5Y9MJgg3BkM4Zve8vb4wQ/114748246746/notes?url=http%3A%2F%2F500sandwiches.com%2Fpost%2F114748246746%2Fmatta-rice%23notes&refUrl=http%3A%2F%2F500sandwiches.com%2Fpost%2F114748246746%2Fmatta-rice%2Fembed&isAMP=false',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/781664613bf5ac4fc2f912b267727487/tumblr_inline_pjzoh7yPiv1qkqibd_500.jpg'}],
#              'cse_thumbnail': [{'height': '60',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQTV_la7Pi5Cf0R_eW5QUXyhUJwotU0L6d8aYHFWC6Pq-9sBjYxivM7C0I',
#                                 'width': '500'}],
#              'metatags': [{'al:android:app_name': 'Tumblr',
#                            'al:android:package': 'com.tumblr',
#                            'al:android:url': 'tumblr://x-callback-url/blog?blogName=500sandwiches&postID=114748246746',
#                            'al:ios:app_name': 'Tumblr',
#                            'al:ios:app_store_id': '305343404',
#                            'al:ios:url': 'tumblr://x-callback-url/blog?blogName=500sandwiches&postID=114748246746',
#                            'apple-itunes-app': 'app-id=305343404,affiliate-data=at=11l3M5&ct=us.itunes.uni.tumblr.ipdt,app-argument=tumblr://x-callback-url/blog?blogName=500sandwiches&postID=114748246746&referrer=smart-app-banner',
#                            'fb:app_id': '48119224995',
#                            'og:description': 'Can we be honest with you? We’re '
#                                              'probably a bit too attached to '
#                                              'our rice cooker. Set it and '
#                                              'forget it. We’ve become lazy, '
#                                              'reliant on an appliance. So what '
#                                              'happens when we want to serve a '
#                                              'rice that’s...',
#                            'og:determiner': 'a',
#                            'og:image': 'https://66.media.tumblr.com/781664613bf5ac4fc2f912b267727487/tumblr_inline_pjzoh7yPiv1qkqibd_500.jpg',
#                            'og:site_name': '500sandwiches',
#                            'og:title': '500sandwiches',
#                            'og:type': 'article',
#                            'og:url': 'http://500sandwiches.com/post/114748246746/matta-rice',
#                            'theme-color': '#35465D',
#                            'viewport': 'width=device-width, initial-scale=1.0, '
#                                        'maximum-scale=1.0, user-scalable=no'}]},
#  'snippet': 'Mar 27, 2015 ... Matta rice is an ancient rice variety hailing '
#             'from Kerala, South India. Its plump \n'
#             'little grains have a softy rosy color – it is also known as '
#             'rosematta\xa0...',
#  'title': "— Can we be honest with you? We're probably a bit..."}
# {'cacheId': 'Ppv1YlYRBMoJ',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/tagged/caitlin+rice',
#  'htmlFormattedUrl': 'https://www.tumblr.com/tagged/caitlin+<b>rice</b>',
#  'htmlSnippet': 'Tumblr is a place to express yourself, discover yourself, and '
#                 'bond over the stuff <br>\n'
#                 'you love. It&#39;s where your interests connect you with your '
#                 'people.',
#  'htmlTitle': 'caitlin <b>rice</b> | Tumblr',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/tagged/caitlin+rice',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/4de4910d1384ce108f84b115f73297f3/tumblr_n7bt3x5nWH1re1zw6o1_400.jpg'}],
#              'cse_thumbnail': [{'height': '275',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQBV1TVBJE-JM5-meprdeCpFGoZk9GLB1A2R2lgCwBF3ta7VykshtbqmBOr',
#                                 'width': '183'}],
#              'metatags': [{'application-name': 'Tumblr',
#                            'msapplication-tilecolor': '#3645d',
#                            'msapplication-tileimage': 'https://assets.tumblr.com/images/msfavicon.png?_v=245323c5cb69e705ea213d9ed60e543a',
#                            'p:domain_verify': 'd06c4fa470a9a6935c9a7b43d57eb7d2',
#                            'theme-color': '#35465D',
#                            'tumblr-form-key': '!1231553680963|tAdKHT4vK84kjceWaVOTrhOWiFM',
#                            'tumblr-gpop': 'Tumblr',
#                            'viewport': 'initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no'}]},
#  'snippet': 'Tumblr is a place to express yourself, discover yourself, and '
#             'bond over the stuff \n'
#             "you love. It's where your interests connect you with your people.",
#  'title': 'caitlin rice | Tumblr'}
# {'cacheId': 'FUt7BJGUApcJ',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/tagged/angourie+rice',
#  'htmlFormattedUrl': 'https://www.tumblr.com/tagged/angourie+<b>rice</b>',
#  'htmlSnippet': 'Shots of Betty Brant (Angourie <b>Rice</b>) with Ned Leeds '
#                 '(Jacob Batalon) in Spider <br>\n'
#                 'Man Far From Home teaser &amp; extended trailer ~ Apparently '
#                 'their ship name is&nbsp;...',
#  'htmlTitle': 'angourie <b>rice</b> | Tumblr',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/tagged/angourie+rice',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/125235f9e2e40e2f845a707f39dd20af/tumblr_ob392xWRgB1sepx2oo4_250.gif'}],
#              'cse_thumbnail': [{'height': '225',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTjb0FtAm4DsQDh_dJlEtFukCl3F_XJFbohMuwueSHs-DRAd6cQDgaWSTP3',
#                                 'width': '225'}],
#              'metatags': [{'application-name': 'Tumblr',
#                            'msapplication-tilecolor': '#3645d',
#                            'msapplication-tileimage': 'https://assets.tumblr.com/images/msfavicon.png?_v=245323c5cb69e705ea213d9ed60e543a',
#                            'p:domain_verify': 'd06c4fa470a9a6935c9a7b43d57eb7d2',
#                            'theme-color': '#35465D',
#                            'tumblr-form-key': '!1231553875688|m29ymbywaTuwjJd7V1fFR1dYMs',
#                            'tumblr-gpop': 'Tumblr',
#                            'viewport': 'initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no'}]},
#  'snippet': 'Shots of Betty Brant (Angourie Rice) with Ned Leeds (Jacob '
#             'Batalon) in Spider \n'
#             'Man Far From Home teaser & extended trailer ~ Apparently their '
#             'ship name is\xa0...',
#  'title': 'angourie rice | Tumblr'}
# {'cacheId': 'yfy7l5vdi90J',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/.../notes?...me%2Fpost%2F2072176364%2Frice... '
#                  'me%2Fpost%2F2072176364%2Frice...',
#  'htmlFormattedUrl': 'https://www.tumblr.com/.../notes?...me%2Fpost%2F2072176364%2F<b>rice</b>... '
#                      'me%2Fpost%2F2072176364%2F<b>rice</b>...',
#  'htmlSnippet': 'Dec 2, 2010 <b>...</b> <b>Rice</b> College Cheers I found '
#                 'this list somewhere. So rather than study for finals, I <br>\n'
#                 'decided it was worthwhile to put here for further reference.',
#  'htmlTitle': 'img/ — <b>Rice</b> College Cheers',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/embed/clickthrough/UHoBYlExKqn4wvCDPBOg4w/2072176364/notes?url=http%3A%2F%2Fblog.capshaw.me%2Fpost%2F2072176364%2Frice-college-cheers%23notes&refUrl=http%3A%2F%2Fblog.capshaw.me%2Fpost%2F2072176364%2Frice-college-cheers%2Fembed&isAMP=false',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/avatar_6e5d48972255_512.pnj'}],
#              'cse_thumbnail': [{'height': '225',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQsO6XAeEw3WV1B4o74uKdamWVnbhe5GLbFcK8Xso-EXoEnmmj3gPjFMNI',
#                                 'width': '225'}],
#              'metatags': [{'al:android:app_name': 'Tumblr',
#                            'al:android:package': 'com.tumblr',
#                            'al:android:url': 'tumblr://x-callback-url/blog?blogName=premendax-blog&postID=2072176364',
#                            'al:ios:app_name': 'Tumblr',
#                            'al:ios:app_store_id': '305343404',
#                            'al:ios:url': 'tumblr://x-callback-url/blog?blogName=premendax-blog&postID=2072176364',
#                            'apple-itunes-app': 'app-id=305343404,affiliate-data=at=11l3M5&ct=us.itunes.uni.tumblr.ipdt,app-argument=tumblr://x-callback-url/blog?blogName=premendax-blog&postID=2072176364&referrer=smart-app-banner',
#                            'fb:app_id': '48119224995',
#                            'og:description': 'I found this list somewhere. So '
#                                              'rather than study for finals, I '
#                                              'decided it was worthwhile to put '
#                                              'here for further reference. '
#                                              'Baker Cheers - Baker Loves Meat\n'
#                                              '-\xa0Baker x infinity\n'
#                                              '-\xa0Baker! Hell...',
#                            'og:determiner': 'a',
#                            'og:image': 'https://66.media.tumblr.com/avatar_6e5d48972255_512.pnj',
#                            'og:site_name': 'img/',
#                            'og:title': 'Rice College Cheers',
#                            'og:type': 'article',
#                            'og:url': 'http://blog.capshaw.me/post/2072176364/rice-college-cheers',
#                            'theme-color': '#35465D',
#                            'viewport': 'width=device-width, initial-scale=1.0, '
#                                        'maximum-scale=1.0, user-scalable=no'}]},
#  'snippet': 'Dec 2, 2010 ... Rice College Cheers I found this list somewhere. '
#             'So rather than study for finals, I \n'
#             'decided it was worthwhile to put here for further reference.',
#  'title': 'img/ — Rice College Cheers'}
# {'cacheId': '8xCpkNmtGU0J',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/.../notes?...rice%23notes...rice%2Fembed...',
#  'htmlFormattedUrl': 'https://www.tumblr.com/.../notes?...<b>rice</b>%23notes...<b>rice</b>%2Fembed...',
#  'htmlSnippet': 'Black Beans and Burmese <b>Rice</b>. image. Does this look '
#                 'familiar? The difference in <br>\n'
#                 'this recipe is I made it with my favorite. I have been eating '
#                 'black beans since I&nbsp;...',
#  'htmlTitle': 'a Love a fare — Black Beans and Burmese <b>Rice</b>',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/embed/clickthrough/hwy9uVPwT-ksRq9cEbtMIA/80252888575/notes?url=http%3A%2F%2Faloveafare.com%2Fpost%2F80252888575%2Fblack-beans-and-burmese-rice%23notes&refUrl=http%3A%2F%2Faloveafare.com%2Fpost%2F80252888575%2Fblack-beans-and-burmese-rice%2Fembed&isAMP=false',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/ab81314de07d47e1535650afefa61a82/tumblr_inline_n06mbxKugL1r4bmc5.jpg'}],
#              'cse_thumbnail': [{'height': '275',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRtkuy71mA1EVGbB_bKCyaAqMzIvpn8VePdIgDdfK7vInXuh66wrImrsWJG',
#                                 'width': '183'}],
#              'metatags': [{'apple-mobile-web-app-capable': 'yes',
#                            'og:description': 'Black Beans and Burmese Rice',
#                            'og:site_name': 'a Love a fare',
#                            'og:title': 'a Love a fare — Black Beans and '
#                                        'Burmese Rice',
#                            'og:type': 'article',
#                            'og:url': 'http://aloveafare.com/post/80252888575/black-beans-and-burmese-rice',
#                            'viewport': 'width=device-width, initial-scale=1.0, '
#                                        'maximum-scale=1.0, user-scalable=0',
#                            '”keywords”': '”,healthy'}]},
#  'snippet': 'Black Beans and Burmese Rice. image. Does this look familiar? The '
#             'difference in \n'
#             'this recipe is I made it with my favorite. I have been eating '
#             'black beans since I\xa0...',
#  'title': 'a Love a fare — Black Beans and Burmese Rice'}
# {'cacheId': 'lnQbLUmtEP0J',
#  'displayLink': 'www.tumblr.com',
#  'formattedUrl': 'https://www.tumblr.com/tagged/rice',
#  'htmlFormattedUrl': 'https://www.tumblr.com/tagged/<b>rice</b>',
#  'htmlSnippet': 'Tegalalang <b>rice</b> terraces looking Who wants to go here '
#                 '... largest population in <br>\n'
#                 'the world?! indonesia produces 70 million tons of <b>rice</b> '
#                 'a year. it&#39;s their staple&nbsp;...',
#  'htmlTitle': '<b>rice</b> | Tumblr',
#  'kind': 'customsearch#result',
#  'link': 'https://www.tumblr.com/tagged/rice',
#  'pagemap': {'cse_image': [{'src': 'https://66.media.tumblr.com/66f1160a1a7d1507b764639e7de7fa6f/tumblr_pjj7fdXtBT1qg00mm_540.jpg'}],
#              'cse_thumbnail': [{'height': '225',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSbIbwjCyLw7ofJWsXf38T-Ln7wnkGl_5AhcaV4MKmASDVjuc8HVzbUVLiS',
#                                 'width': '225'}],
#              'metatags': [{'application-name': 'Tumblr',
#                            'msapplication-tilecolor': '#3645d',
#                            'msapplication-tileimage': 'https://assets.tumblr.com/images/msfavicon.png?_v=245323c5cb69e705ea213d9ed60e543a',
#                            'p:domain_verify': 'd06c4fa470a9a6935c9a7b43d57eb7d2',
#                            'theme-color': '#35465D',
#                            'tumblr-form-key': '!1231553916810|Qsp71bwR4RGoElOEXhwV0pP3NlI',
#                            'tumblr-gpop': 'Tumblr',
#                            'viewport': 'initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no'}]},
#  'snippet': 'Tegalalang rice terraces looking Who wants to go here ... largest '
#             'population in \n'
#             'the world?! indonesia produces 70 million tons of rice a year. '
#             "it's their staple\xa0...",
#  'title': 'rice | Tumblr'}

# %%
#results[0]

# %%
# for i in range(len(results)):
#     print(results[i])

# %%
#results[0]

# %%
#url = results[0]['pagemap']['cse_image'][0]['src']

# %%
from PIL import Image
import requests
from io import BytesIO

# response = requests.get(url)
# img = Image.open(BytesIO(response.content))

# %%
#img.show()

# %%
for i in range(len(results)):
    url = results[i]['pagemap']['cse_image'][0]['src']
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img.save(str(i)+".png")
